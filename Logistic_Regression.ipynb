# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaPremaseelan/Machine-Learning-Codes-Implemented-using-Packages/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/logistic_regression/insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.describe()
# Out:
#              age  bought_insurance
# count  27.000000         27.000000
# mean   39.666667          0.518519
# std    15.745573          0.509175
# min    18.000000          0.000000
# 25%    25.000000          0.000000
# 50%    45.000000          1.000000
# 75%    54.500000          1.000000
# max    62.000000          1.000000

# %%
df['bought_insurance'].unique()
# Out:
# array([0, 1])

# %%
df['bought_insurance'].nunique()
# Out:
# 2

# %%
df['bought_insurance'].value_counts()
# Out:
# 1    14
# 0    13
# Name: bought_insurance, dtype: int64

# %%
x=df.drop('bought_insurance',axis='columns')
x
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
y=df.bought_insurance
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn import linear_model

# %%
model=linear_model.LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
print('Total',len(x))
print('Train size',len(x_train))
print('Test size',len(x_test))
# Out:
# Total 27
# Train size 21
# Test size 6

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [[0.15694267]]
# [-5.72886773]

# %%
y_predicted=model.predict(x_test)
y_predicted
# Out:
# array([1, 0, 0, 1, 1, 0])

# %%
print('Test data score',model.score(x_test,y_test))
print('Train data score',model.score(x_train,y_train))
# Out:
# Test data score 0.8333333333333334
# Train data score 0.9047619047619048
